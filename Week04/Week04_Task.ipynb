# %% [markdown]
# # Week 04 Task
# 📌 Task 01: Image Filtering with Convolution
#
# 1. Select one real image from your mobile or download from the internet.
# 2. Write a Python program to apply the following filters:
#    a. Blur Filter
#    b. Sharpen Filter
#    c. Edge Detection (Sobel)
# 3. Display all results along with the original image.
# 4. Write a short explanation (5–6 lines) on how each filter changed the image and
#    where such filters are used in real-life applications (CCTV, Face Recognition, Robo Vision, etc.).
#
# Submit: .ipynb file + screenshots of output.
# Deadline: Next class.

# %% [markdown]
# 📌 Task 02: Image Stylization using Emboss Convolution Filter
#
# The emboss filter highlights the edges and surface details of an image and makes it look as if it has been carved onto a metal or stone surface.
#
# You will work with one original image and produce its embossed version using a convolution kernel (take an emboss filter from google).
# This task helps you understand how convolution filters can be used not just for analysis, but also for stylizing and enhancing visual appearance, which is widely used in graphic design, art filters, and photo editing apps.
#
# Original Image
#
# ![frameman1-300x300.jpeg](attachment:frameman1-300x300.jpeg)
#
# Embossed Image
#
# ![223-1-300x300.png](attachment:223-1-300x300.png)
#
#
# **Hint:** convert the original image to grayscale via, <br>
# grayscale = cv2.imread('image path', cv2.IMREAD_GRAYSCALE)

# %% [markdown]
# # UNSHARP MASKING AND HIGHBOOST FILTERING
# Subtracting an unsharp (smoothed) version of an image from the original image is
# process that has been used since the 1930s by the printing and publishing industry to
# sharpen images. This process, called unsharp masking, consists of the following steps:
# 1. Blur the original image.
# 2. Subtract the blurred image from the original (the resulting difference is called
# the mask.)
# 3. Add the mask to the original.
#
#  Letting b(x,y) denote the blurred image, the mask in equation form is given by:<br>
# $$m(x,y) = f(x,y) - b(x,y)$$
# Then we add a weighted portion of the mask back to the original image:
# $$g(x,y) = f(x,y) - km(x,y)$$
#
#  where we included a weight, k (k=>1) for generality. When k = 1 we have unsharp
# masking, as defined above. When k > 1, the process is referred to as highboost filtering.
#
# 📌 Task 03: Use Unsharp Masking and Highboost Filtering to obtain the following results
#
# 1. Original Image of size 600x259 pixels
# 2. Image blurred using 31x31 Guassian Filter with sigma = 5.
# 3. Mask
# 4. Result of unsharp masking using eq. with k = 1.
# 5. Result of Highboost Filtering with k = 4.5
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)
